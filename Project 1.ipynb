# %% [markdown]
# # Fortune 500 HQs and Impact on Local Economies

# %%
#dependencies
import pandas as pd
import csv
import numpy as np
import requests
import json
import matplotlib.pyplot as plt
from config import g_key
from config import bls_key
import geocoder

# %%
#importing fortune 500 HQs
fortune500HQ_to_load = "./Data_Files/Fortune_500.csv"
Fortune_500 = pd.read_csv(fortune500HQ_to_load)

Fortune_500.head()
# Out:
#    Rank               Title                           Website  Employees  \
# 0     1             Walmart            http://www.walmart.com    2300000
# 1     2  Berkshire Hathaway  http://www.berkshirehathaway.com     367700
# 2     3               Apple              http://www.apple.com     116000
# 3     4         Exxon Mobil         http://www.exxonmobil.com      72700
# 4     5            McKesson           http://www.mckesson.com      68000
#
#         Sector                                  Industry         Hqlocation  \
# 0    Retailing                     General Merchandisers    Bentonville, AR
# 1   Financials  Insurance: Property and Casualty (Stock)          Omaha, NE
# 2   Technology               Computers, Office Equipment      Cupertino, CA
# 3       Energy                        Petroleum Refining         Irving, TX
# 4  Wholesalers                  Wholesalers: Health Care  San Francisco, CA
#
#                    Hqaddr         Hqcity Hqstate     ...       \
# 0     702 S.W. Eighth St.    Bentonville      AR     ...
# 1         3555 Farnam St.          Omaha      NE     ...
# 2         1 Infinite Loop      Cupertino      CA     ...
# 3  5959 Las Colinas Blvd.         Irving      TX     ...
# 4              1 Post St.  San Francisco      CA     ...
#
#                                        Ceo-title  \
# 0  President, Chief Executive Officer & Director
# 1             Chairman & Chief Executive Officer
# 2             Chief Executive Officer & Director
# 3             Chairman & Chief Executive Officer
# 4  Chairman, President & Chief Executive Officer
#
#                                       Address Ticker                 Fullname  \
# 0  702 S.W. Eighth St., Bentonville, AR 72716    WMT    Wal-Mart Stores, Inc.
# 1            3555 Farnam St., Omaha, NE 68131   BRKA  Berkshire Hathaway Inc.
# 2        1 Infinite Loop, Cupertino, CA 95014   AAPL              Apple, Inc.
# 3    5959 Las Colinas Blvd., Irving, TX 75039    XOM  Exxon Mobil Corporation
# 4         1 Post St., San Francisco, CA 94104    MCK     McKesson Corporation
#
#   Revenues Revchange  Profits  Prftchange  Assets  Totshequity
# 0   485873       0.8  13643.0        -7.2  198825      77798.0
# 1   223604       6.1  24074.0           0  620854     283001.0
# 2   215639      -7.7  45687.0       -14.4  321686     128249.0
# 3   205004     -16.7   7840.0       -51.5  330314     167325.0
# 4   192487       6.2   2258.0          53   56563       8924.0
#
# [5 rows x 23 columns]

# %%
counties = []

for row in range(0, len(Fortune_500)):
    city = Fortune_500["Hqcity"][row]
    state = Fortune_500["Hqstate"][row]
    results = geocoder.google(f"{city},{state}", key=g_key)
    
    # Use conditional to set county equal to city name if no county is available
    if results = "None":
        counties.append(f"{city} City")
    else:
        counties.append(results.county)
    
Fortune_500["County"]=counties
Fortune_500.head()
# Out:
#    Rank               Title                           Website  Employees  \
# 0     1             Walmart            http://www.walmart.com    2300000
# 1     2  Berkshire Hathaway  http://www.berkshirehathaway.com     367700
# 2     3               Apple              http://www.apple.com     116000
# 3     4         Exxon Mobil         http://www.exxonmobil.com      72700
# 4     5            McKesson           http://www.mckesson.com      68000
#
#         Sector                                  Industry         Hqlocation  \
# 0    Retailing                     General Merchandisers    Bentonville, AR
# 1   Financials  Insurance: Property and Casualty (Stock)          Omaha, NE
# 2   Technology               Computers, Office Equipment      Cupertino, CA
# 3       Energy                        Petroleum Refining         Irving, TX
# 4  Wholesalers                  Wholesalers: Health Care  San Francisco, CA
#
#                    Hqaddr         Hqcity Hqstate          ...           \
# 0     702 S.W. Eighth St.    Bentonville      AR          ...
# 1         3555 Farnam St.          Omaha      NE          ...
# 2         1 Infinite Loop      Cupertino      CA          ...
# 3  5959 Las Colinas Blvd.         Irving      TX          ...
# 4              1 Post St.  San Francisco      CA          ...
#
#                                       Address Ticker                 Fullname  \
# 0  702 S.W. Eighth St., Bentonville, AR 72716    WMT    Wal-Mart Stores, Inc.
# 1            3555 Farnam St., Omaha, NE 68131   BRKA  Berkshire Hathaway Inc.
# 2        1 Infinite Loop, Cupertino, CA 95014   AAPL              Apple, Inc.
# 3    5959 Las Colinas Blvd., Irving, TX 75039    XOM  Exxon Mobil Corporation
# 4         1 Post St., San Francisco, CA 94104    MCK     McKesson Corporation
#
#   Revenues Revchange  Profits Prftchange  Assets  Totshequity  \
# 0   485873       0.8  13643.0       -7.2  198825      77798.0
# 1   223604       6.1  24074.0          0  620854     283001.0
# 2   215639      -7.7  45687.0      -14.4  321686     128249.0
# 3   205004     -16.7   7840.0      -51.5  330314     167325.0
# 4   192487       6.2   2258.0         53   56563       8924.0
#
#                  County
# 0         Benton County
# 1        Douglas County
# 2    Santa Clara County
# 3         Dallas County
# 4  San Francisco County
#
# [5 rows x 24 columns]

# %%
zip_codes = []

for row in range(0, len(Fortune_500)):
    address_split = Fortune_500["Address"][row].split()
    zip_codes.append(address_split[-1])
    
Fortune_500["Zip Code"] = zip_codes
Fortune_500.head()
# Out:
#    Rank               Title                           Website  Employees  \
# 0     1             Walmart            http://www.walmart.com    2300000
# 1     2  Berkshire Hathaway  http://www.berkshirehathaway.com     367700
# 2     3               Apple              http://www.apple.com     116000
# 3     4         Exxon Mobil         http://www.exxonmobil.com      72700
# 4     5            McKesson           http://www.mckesson.com      68000
#
#         Sector                                  Industry         Hqlocation  \
# 0    Retailing                     General Merchandisers    Bentonville, AR
# 1   Financials  Insurance: Property and Casualty (Stock)          Omaha, NE
# 2   Technology               Computers, Office Equipment      Cupertino, CA
# 3       Energy                        Petroleum Refining         Irving, TX
# 4  Wholesalers                  Wholesalers: Health Care  San Francisco, CA
#
#                    Hqaddr         Hqcity Hqstate    ...     Ticker  \
# 0     702 S.W. Eighth St.    Bentonville      AR    ...        WMT
# 1         3555 Farnam St.          Omaha      NE    ...       BRKA
# 2         1 Infinite Loop      Cupertino      CA    ...       AAPL
# 3  5959 Las Colinas Blvd.         Irving      TX    ...        XOM
# 4              1 Post St.  San Francisco      CA    ...        MCK
#
#                   Fullname Revenues Revchange  Profits Prftchange  Assets  \
# 0    Wal-Mart Stores, Inc.   485873       0.8  13643.0       -7.2  198825
# 1  Berkshire Hathaway Inc.   223604       6.1  24074.0          0  620854
# 2              Apple, Inc.   215639      -7.7  45687.0      -14.4  321686
# 3  Exxon Mobil Corporation   205004     -16.7   7840.0      -51.5  330314
# 4     McKesson Corporation   192487       6.2   2258.0         53   56563
#
#    Totshequity                County  Zip Code
# 0      77798.0         Benton County     72716
# 1     283001.0        Douglas County     68131
# 2     128249.0    Santa Clara County     95014
# 3     167325.0         Dallas County     75039
# 4       8924.0  San Francisco County     94104
#
# [5 rows x 25 columns]

# %%
no_county = Fortune_500.loc[Fortune_500["County"].isna() == True]
no_county.head(100)
# Out:
#      Rank                              Title  \
# 13     14                            Verizon
# 20     21                  J.P. Morgan Chase
# 21     22            Express Scripts Holding
# 29     30                          Citigroup
# 41     42                            MetLife
# 53     54                             Pfizer
# 54     55                                AIG
# 64     65            New York Life Insurance
# 65     66                            Centene
# 75     76                     Morgan Stanley
# 77     78                Goldman Sachs Group
# 79     80                               TIAA
# 85     86                   American Express
# 89     90                   General Dynamics
# 94     95                        Time Warner
# 98     99                     Travelers Cos.
# 100   101           Twenty-First Century Fox
# 103   104        Philip Morris International
# 113   114                   Northrop Grumman
# 135   136                        Dollar Tree
# 138   139                   Emerson Electric
# 146   147               Bristol-Myers Squibb
# 147   148                       Altria Group
# 167   168                  Icahn Enterprises
# 170   171             Performance Food Group
# 173   174                             CarMax
# 176   177            Bank of New York Mellon
# 178   179                      Omnicom Group
# 181   182                  Colgate-Palmolive
# 188   189                       INTL FCStone
# ..    ...                                ...
# 209   210                   Marsh & McLennan
# 212   213                              Loews
# 217   218  Guardian Life Ins. Co. of America
# 223   224                             Viacom
# 227   228                            Arconic
# 233   234                Consolidated Edison
# 237   238                    Dominion Energy
# 252   253                       Estee Lauder
# 254   255                          BlackRock
# 261   262                  Leucadia National
# 265   266                     Voya Financial
# 272   273                    L3 Technologies
# 283   284                   Norfolk Southern
# 291   292                 Advance Auto Parts
# 299   300                              Alcoa
# 328   329                 Genworth Financial
# 331   332                         News Corp.
# 334   335                                PVH
# 344   345                  Interpublic Group
# 347   348                        Foot Locker
# 360   361                           Assurant
# 370   371                       Ralph Lauren
# 379   380      Huntington Ingalls Industries
# 417   418                          HRG Group
# 419   420                   Graybar Electric
# 427   428                          Alleghany
# 430   431                             Ameren
# 458   459                         S&P Global
# 474   475         AmTrust Financial Services
# 499   500                     ABM Industries
#
#                                  Website  Employees  \
# 13                http://www.verizon.com     160900
# 20          http://www.jpmorganchase.com     243355
# 21        http://www.express-scripts.com      25600
# 29              http://www.citigroup.com     219000
# 41                http://www.metlife.com      58000
# 53                 http://www.pfizer.com      96500
# 54                    http://www.aig.com      56400
# 64            http://www.newyorklife.com      11320
# 65                http://www.centene.com      30500
# 75          http://www.morganstanley.com      55311
# 77                     http://www.gs.com      34400
# 79                   http://www.tiaa.org      12997
# 85        http://www.americanexpress.com      56400
# 89        http://www.generaldynamics.com      98800
# 94             http://www.timewarner.com      25000
# 98              http://www.travelers.com      30900
# 100                  http://www.21cf.com      21500
# 103                   http://www.pmi.com      79500
# 113       http://www.northropgrumman.com      67000
# 135            http://www.dollartree.com     116050
# 138               http://www.emerson.com     103500
# 146                   http://www.bms.com      25000
# 147                http://www.altria.com       8300
# 167                  http://www.ielp.com      90980
# 170                  http://www.pfgc.com      13000
# 173                http://www.carmax.com      22429
# 176             http://www.bnymellon.com      52000
# 178          http://www.omnicomgroup.com      78500
# 181      http://www.colgatepalmolive.com      36700
# 188           http://www.intlfcstone.com       1464
# ..                                   ...        ...
# 209                   http://www.mmc.com      60000
# 212                 http://www.loews.com      15800
# 217          http://www.guardianlife.com       8876
# 223                http://www.viacom.com       9650
# 227               http://www.arconic.com      41500
# 233             http://www.conedison.com      14960
# 237        http://www.dominionenergy.com      16200
# 252           http://www.elcompanies.com      46000
# 254             http://www.blackrock.com      13000
# 261              http://www.leucadia.com      13000
# 265                  http://www.voya.com       6700
# 272                   http://www.l3t.com      38000
# 283                http://www.nscorp.com      27856
# 291      http://www.advanceautoparts.com      57500
# 299                 http://www.alcoa.com      14000
# 328              http://www.genworth.com       3400
# 331              http://www.newscorp.com      24000
# 334                   http://www.pvh.com      26650
# 344           http://www.interpublic.com      49800
# 347        http://www.footlocker-inc.com      32965
# 360              http://www.assurant.com      14700
# 370           http://www.ralphlauren.com      20500
# 379  http://www.huntingtoningalls.com%20      37000
# 417              http://www.hrggroup.com      16021
# 419               http://www.graybar.com       8500
# 427             http://www.alleghany.com       3420
# 430                http://www.ameren.com       8629
# 458              http://www.spglobal.com      20000
# 474          http://www.amtrustgroup.com       8000
# 499                   http://www.abm.com     110000
#
#                         Sector                                  Industry  \
# 13          Telecommunications                        Telecommunications
# 20                  Financials                          Commercial Banks
# 21                 Health Care  Health Care: Pharmacy and Other Services
# 29                  Financials                          Commercial Banks
# 41                  Financials           Insurance: Life, Health (Stock)
# 53                 Health Care                           Pharmaceuticals
# 54                  Financials  Insurance: Property and Casualty (Stock)
# 64                  Financials          Insurance: Life, Health (Mutual)
# 65                 Health Care   Health Care: Insurance and Managed Care
# 75                  Financials                          Commercial Banks
# 77                  Financials                          Commercial Banks
# 79                  Financials          Insurance: Life, Health (Mutual)
# 85                  Financials                    Diversified Financials
# 89         Aerospace & Defense                     Aerospace and Defense
# 94                       Media                             Entertainment
# 98                  Financials  Insurance: Property and Casualty (Stock)
# 100                      Media                             Entertainment
# 103  Food, Beverages & Tobacco                                   Tobacco
# 113        Aerospace & Defense                     Aerospace and Defense
# 135                  Retailing                Specialty Retailers: Other
# 138                Industrials         Electronics, Electrical Equipment
# 146                Health Care                           Pharmaceuticals
# 147  Food, Beverages & Tobacco                                   Tobacco
# 167                 Financials                    Diversified Financials
# 170                Wholesalers             Wholesalers: Food and Grocery
# 173                  Retailing            Automotive Retailing, Services
# 176                 Financials                          Commercial Banks
# 178          Business Services                    Advertising, Marketing
# 181         Household Products           Household and Personal Products
# 188                 Financials                    Diversified Financials
# ..                         ...                                       ...
# 209                 Financials                    Diversified Financials
# 212                 Financials  Insurance: Property and Casualty (Stock)
# 217                 Financials          Insurance: Life, Health (Mutual)
# 223                      Media                             Entertainment
# 227        Aerospace & Defense                     Aerospace and Defense
# 233                     Energy               Utilities: Gas and Electric
# 237                     Energy               Utilities: Gas and Electric
# 252         Household Products           Household and Personal Products
# 254                 Financials                                Securities
# 261                 Financials                    Diversified Financials
# 265                 Financials                    Diversified Financials
# 272        Aerospace & Defense                     Aerospace and Defense
# 283             Transportation                                 Railroads
# 291                  Retailing                Specialty Retailers: Other
# 299                  Materials                                    Metals
# 328                 Financials           Insurance: Life, Health (Stock)
# 331                      Media                      Publishing, Printing
# 334                    Apparel                                   Apparel
# 344          Business Services                    Advertising, Marketing
# 347                  Retailing              Specialty Retailers: Apparel
# 360                 Financials  Insurance: Property and Casualty (Stock)
# 370                    Apparel                                   Apparel
# 379        Aerospace & Defense                     Aerospace and Defense
# 417         Household Products           Household and Personal Products
# 419                Wholesalers                  Wholesalers: Diversified
# 427                 Financials  Insurance: Property and Casualty (Stock)
# 430                     Energy               Utilities: Gas and Electric
# 458          Business Services                   Financial Data Services
# 474                 Financials  Insurance: Property and Casualty (Stock)
# 499          Business Services          Diversified Outsourcing Services
#
#            Hqlocation                      Hqaddr        Hqcity Hqstate  \
# 13       New York, NY   1095 Ave. of the Americas      New York      NY
# 20       New York, NY               270 Park Ave.      New York      NY
# 21      St. Louis, MO               1 Express Way     St. Louis      MO
# 29       New York, NY           388 Greenwich St.      New York      NY
# 41       New York, NY               200 Park Ave.      New York      NY
# 53       New York, NY             235 E. 42nd St.      New York      NY
# 54       New York, NY               175 Water St.      New York      NY
# 64       New York, NY             51 Madison Ave.      New York      NY
# 65      St. Louis, MO          7700 Forsyth Blvd.     St. Louis      MO
# 75       New York, NY               1585 Broadway      New York      NY
# 77       New York, NY                200 West St.      New York      NY
# 79       New York, NY              730 Third Ave.      New York      NY
# 85       New York, NY               200 Vesey St.      New York      NY
# 89   Falls Church, VA      2941 Fairview Park Dr.  Falls Church      VA
# 94       New York, NY        1 Time Warner Center      New York      NY
# 98       New York, NY          485 Lexington Ave.      New York      NY
# 100      New York, NY   1211 Ave. of the Americas      New York      NY
# 103      New York, NY               120 Park Ave.      New York      NY
# 113  Falls Church, VA      2980 Fairview Park Dr.  Falls Church      VA
# 135    Chesapeake, VA             500 Volvo Pkwy.    Chesapeake      VA
# 138     St. Louis, MO     8000 W. Florissant Ave.     St. Louis      MO
# 146      New York, NY               345 Park Ave.      New York      NY
# 147      Richmond, VA           6601 W. Broad St.      Richmond      VA
# 167      New York, NY              767 Fifth Ave.      New York      NY
# 170      Richmond, VA        12500 W. Creek Pkwy.      Richmond      VA
# 173      Richmond, VA  12800 Tuckahoe Creek Pkwy.      Richmond      VA
# 176      New York, NY             225 Liberty St.      New York      NY
# 178      New York, NY            437 Madison Ave.      New York      NY
# 181      New York, NY               300 Park Ave.      New York      NY
# 188      New York, NY              708 Third Ave.      New York      NY
# ..                ...                         ...           ...     ...
# 209      New York, NY   1166 Ave. of the Americas      New York      NY
# 212      New York, NY            667 Madison Ave.      New York      NY
# 217      New York, NY               7 Hanover Sq.      New York      NY
# 223      New York, NY               1515 Broadway      New York      NY
# 227      New York, NY               390 Park Ave.      New York      NY
# 233      New York, NY              4 Irving Place      New York      NY
# 237      Richmond, VA            120 Tredegar St.      Richmond      VA
# 252      New York, NY              767 Fifth Ave.      New York      NY
# 254      New York, NY              55 E. 52nd St.      New York      NY
# 261      New York, NY            520 Madison Ave.      New York      NY
# 265      New York, NY               230 Park Ave.      New York      NY
# 272      New York, NY              600 Third Ave.      New York      NY
# 283       Norfolk, VA          3 Commercial Place       Norfolk      VA
# 291       Roanoke, VA            5008 Airport Rd.       Roanoke      VA
# 299      New York, NY               390 Park Ave.      New York      NY
# 328      Richmond, VA           6620 W. Broad St.      Richmond      VA
# 331      New York, NY   1211 Ave. of the Americas      New York      NY
# 334      New York, NY            200 Madison Ave.      New York      NY
# 344      New York, NY              909 Third Ave.      New York      NY
# 347      New York, NY             330 W. 34th St.      New York      NY
# 360      New York, NY              28 Liberty St.      New York      NY
# 370      New York, NY            650 Madison Ave.      New York      NY
# 379  Newport News, VA        4101 Washington Ave.  Newport News      VA
# 417      New York, NY               450 Park Ave.      New York      NY
# 419     St. Louis, MO          34 N. Meramec Ave.     St. Louis      MO
# 427      New York, NY               1411 Broadway      New York      NY
# 430     St. Louis, MO          1901 Chouteau Ave.     St. Louis      MO
# 458      New York, NY                55 Water St.      New York      NY
# 474      New York, NY              59 Maiden Lane      New York      NY
# 499      New York, NY             1 Liberty Plaza      New York      NY
#
#        ...     Ticker                                    Fullname Revenues  \
# 13     ...         VZ                 Verizon Communications Inc.   125980
# 20     ...        JPM                        JPMorgan Chase & Co.   105486
# 21     ...       ESRX             Express Scripts Holding Company   100288
# 29     ...          C                              Citigroup Inc.    82386
# 41     ...        MET                               MetLife, Inc.    63476
# 53     ...        PFE                                 Pfizer Inc.    52824
# 54     ...        AIG          American International Group, Inc.    52367
# 64     ...         KO             New York Life Insurance Company    40787
# 65     ...        CNC                         Centene Corporation    40721
# 75     ...         MS                              Morgan Stanley    37949
# 77     ...         GS               The Goldman Sachs Group, Inc.    37712
# 79     ...        ETE  Teachers Insurance and Annuity Association    37105
# 85     ...        AXP                    American Express Company    33823
# 89     ...         GD                General Dynamics Corporation    31353
# 94     ...        TWX                            Time Warner Inc.    29318
# 98     ...        TRV               The Travelers Companies, Inc.    27625
# 100    ...       FOXA              Twenty-First Century Fox, Inc.    27326
# 103    ...         PM            Philip Morris International Inc.    26685
# 113    ...        NOC                Northrop Grumman Corporation    24508
# 135    ...       DLTR                           Dollar Tree, Inc.    20719
# 138    ...        EMR                        Emerson Electric Co.    20268
# 146    ...        BMY                Bristol-Myers Squibb Company    19427
# 147    ...         MO                          Altria Group, Inc.    19337
# 167    ...        IEP                      Icahn Enterprises L.P.    16348
# 170    ...       PFGC              Performance Food Group Company    16105
# 173    ...        KMX                                CarMax, Inc.    15833
# 176    ...         BK     The Bank of New York Mellon Corporation    15683
# 178    ...        OMC                          Omnicom Group Inc.    15417
# 181    ...         CL                   Colgate-Palmolive Company    15195
# 188    ...       INTL                           INTL FCStone Inc.    14755
# ..     ...        ...                                         ...      ...
# 209    ...        MMC            Marsh & McLennan Companies, Inc.    13211
# 212    ...          L                           Loews Corporation    13105
# 217    ...        WDC           Guardian Life Ins. Co. of America    12919
# 223    ...       VIAB                                 Viacom Inc.    12488
# 227    ...       ARNC                                Arconic Inc.    12394
# 233    ...         ED                   Consolidated Edison, Inc.    12075
# 237    ...          D                       Dominion Energy, Inc.    11737
# 252    ...         EL             The Estee Lauder Companies Inc.    11262
# 254    ...        BLK                             BlackRock, Inc.    11155
# 261    ...        LUK               Leucadia National Corporation    10875
# 265    ...       VOYA                        Voya Financial, Inc.    10782
# 272    ...        LLL                       L3 Technologies, Inc.    10597
# 283    ...        NSC                Norfolk Southern Corporation     9888
# 291    ...        AAP                    Advance Auto Parts, Inc.     9568
# 299    ...         AA                           Alcoa Corporation     9318
# 328    ...        GNW                    Genworth Financial, Inc.     8369
# 331    ...       NWSA                            News Corporation     8319
# 334    ...        PVH                                   PVH Corp.     8203
# 344    ...        IPG    The Interpublic Group of Companies, Inc.     7847
# 347    ...         FL                           Foot Locker, Inc.     7766
# 360    ...        AIZ                              Assurant, Inc.     7532
# 370    ...         RL                    Ralph Lauren Corporation     7405
# 379    ...        HII         Huntington Ingalls Industries, Inc.     7068
# 417    ...        HRG                             HRG Group, Inc.     6403
# 419    ...        CMS              Graybar Electric Company, Inc.     6385
# 427    ...          Y                       Alleghany Corporation     6131
# 430    ...        AEE                          Ameren Corporation     6076
# 458    ...       SPGI                             S&P Global Inc.     5661
# 474    ...       AFSI            AmTrust Financial Services, Inc.     5451
# 499    ...        ABM                 ABM Industries Incorporated     5145
#
#     Revchange  Profits Prftchange   Assets  Totshequity  County  Zip Code
# 13       -4.3  13127.0      -26.6   244180      22524.0    None     10036
# 20        4.4  24733.0        1.2  2490972     254190.0    None     10017
# 21       -1.4   3404.4       37.5    51745      16236.0    None     63121
# 29       -6.7  14912.0      -13.5  1792077     225120.0    None     10013
# 41       -9.3    800.0      -84.9   898764      67309.0    None     10166
# 53        8.1   7215.0        3.7   171615      59544.0    None     10017
# 54      -10.2   -849.0     -138.7   498264      76300.0    None     10038
# 64      -11.1   1088.1      324.1   287196      20108.0    None     10010
# 65       78.6    562.0       58.3    20197       5895.0    None     63105
# 75        0.1   5979.0       -2.4   814949      76050.0    None     10036
# 77       -3.8   7398.0       21.6   860165      86893.0    None     10282
# 79        5.5   1492.3       22.9   523194      35583.0    None     10017
# 85       -1.8   5408.0        4.7   158893      20501.0    None     10285
# 89       -0.4   2955.0       -0.3    32872      10976.0    None     22042
# 94        4.3   3926.0        2.4    65966      24335.0    None     10019
# 98        3.1   3014.0      -12.4   100245      23221.0    None     10017
# 100      -5.7   2755.0      -66.8    48365      13661.0    None     10036
# 103      -0.4   6967.0        1.4    36851     -12688.0    None     10017
# 113       4.2   2200.0       10.6    25614       5259.0    None     22042
# 135      33.7    896.2      217.4    15702       5390.0    None     23320
# 138      -9.1   1635.0      -39.7    21743       7568.0    None     63136
# 146      17.3   4457.0      184.8    33707      16177.0    None     10154
# 147       2.6  14239.0      171.7    45932      12770.0    None     23230
# 167       7.0  -1128.0      -70.2    33335       2154.0    None     10153
# 170       5.5     68.3       20.9     3455        803.0    None     23238
# 173       6.4    623.4        4.4    14482       2905.0    None     23238
# 176       1.0   3547.0       12.3   333469      38811.0    None     10286
# 178       1.9   1148.6          5    23165       2162.0    None     10022
# 181      -5.2   2441.0       76.4    12123       -243.0    None     10022
# 188     -57.5     54.7       -1.8     5951        434.0    None     10017
# ..        ...      ...        ...      ...          ...     ...       ...
# 209       2.5   1768.0       10.6    18190       6192.0    None     10036
# 212      -2.3    654.0      151.5    76594      18163.0    None     10065
# 217       2.3    263.9      -35.7    70339       6172.5    None     10004
# 223      -5.9   1438.0      -25.2    22508       4277.0    None     10036
# 227     -45.0   -941.0        6.7    20038       5115.0    None     10022
# 233      -3.8   1245.0        4.4    48255      14298.0    None     10003
# 237       0.5   2123.0       11.8    71610      14605.0    None     23219
# 252       4.5   1114.6        2.4     9223       3572.0    None     10153
# 254      -2.2   3172.0       -5.2   220177      29098.0    None     10055
# 261      -6.9    130.0      -54.2    45071      10128.0    None     10022
# 265      -4.9   -428.0     -204.8   214235      12994.0    None     10169
# 272      -8.3    710.0       19.4    11865       4553.0    None     10016
# 283      -5.9   1668.0        7.2    34892      12409.0    None     23510
# 291      -1.7    459.6       -2.9     8315       2916.0    None     24012
# 299       3.0   -400.0      -18.3    16741       5654.0    None     10022
# 328      -9.5   -277.0       -385   104658      12644.0    None     23230
# 331      -3.6    179.0      -21.3    15483      11564.0    None     10036
# 334       2.3    549.0       -4.1    11068       4805.0    None     10016
# 344       3.1    608.5       33.9    12485       2017.0    None     10022
# 347       4.8    664.0       22.7     3840       2710.0    None     10001
# 360     -27.1    565.4      299.4    29709       4098.0    None     10005
# 370      -2.8    396.0      -43.6     6213       3744.0    None     10022
# 379       0.7    573.0       41.8     6352       1653.0    None     23607
# 417      10.1   -198.8      -37.2    35793        638.0    None     10022
# 419       4.5     93.1        2.2     2099        728.0    None     63105
# 427      22.6    456.9      -18.5    23757       7940.0    None     10018
# 430      -0.4    653.0        3.7    24699       7103.0    None     63103
# 458       6.6   2106.0       82.2     8669        650.0    None     10041
# 474      18.1    411.0       -8.8    22615       3269.0    None     10038
# 499      -2.8     57.2        -25     2281        974.0    None     10006
#
# [63 rows x 25 columns]

# %% [markdown]
# # Eric

# %%
# Read unemployment csv into a dataframe
unemployment_file = pd.read_csv("./Data_Files/unemployment.csv", header=None, encoding="iso-8859-1")
unemployment_file.head(20)
# Out:
#                                                     0      1       2  \
# 0   Labor force data by county, not seasonally adj...    NaN     NaN
# 1                                                 NaN    NaN     NaN
# 2                                                 NaN  State  County
# 3                                                 NaN   FIPS    FIPS
# 4                                           LAUS Code   Code    Code
# 5                                                 NaN    NaN     NaN
# 6                                     CN0100100000000     01     001
# 7                                     CN0100300000000     01     003
# 8                                     CN0100500000000     01     005
# 9                                     CN0100700000000     01     007
# 10                                    CN0100900000000     01     009
# 11                                    CN0101100000000     01     011
# 12                                    CN0101300000000     01     013
# 13                                    CN0101500000000     01     015
# 14                                    CN0101700000000     01     017
# 15                                    CN0101900000000     01     019
# 16                                    CN0102100000000     01     021
# 17                                    CN0102300000000     01     023
# 18                                    CN0102500000000     01     025
# 19                                    CN0102700000000     01     027
#
#                                  3       4            5            6  \
# 0                              NaN     NaN          NaN          NaN
# 1                              NaN     NaN          NaN          NaN
# 2                              NaN     NaN          NaN          NaN
# 3                              NaN     NaN        Labor          NaN
# 4   County Name/State Abbreviation  Period        Force     Employed
# 5                              NaN     NaN          NaN          NaN
# 6               Autauga County, AL  Nov-17  25,871       25,085
# 7               Baldwin County, AL  Nov-17  90,382       87,439
# 8               Barbour County, AL  Nov-17   8,148        7,766
# 9                  Bibb County, AL  Nov-17   8,455        8,177
# 10               Blount County, AL  Nov-17  24,396       23,641
# 11              Bullock County, AL  Nov-17   4,832        4,636
# 12               Butler County, AL  Nov-17   8,842        8,462
# 13              Calhoun County, AL  Nov-17  45,351       43,587
# 14             Chambers County, AL  Nov-17  15,210       14,701
# 15             Cherokee County, AL  Nov-17  11,027       10,671
# 16              Chilton County, AL  Nov-17  19,078       18,478
# 17              Choctaw County, AL  Nov-17   4,311        4,082
# 18               Clarke County, AL  Nov-17   7,559        7,072
# 19                 Clay County, AL  Nov-17   5,714        5,515
#
#              7          8
# 0          NaN        NaN
# 1          NaN        NaN
# 2          NaN  Unemploy-
# 3          NaN  ment Rate
# 4   Unemployed        (%)
# 5          NaN        NaN
# 6     786        3.0
# 7   2,943        3.3
# 8     382        4.7
# 9     278        3.3
# 10    755        3.1
# 11    196        4.1
# 12    380        4.3
# 13  1,764        3.9
# 14    509        3.3
# 15    356        3.2
# 16    600        3.1
# 17    229        5.3
# 18    487        6.4
# 19    199        3.5

# %%
# Rename columns
unemployment_df = unemployment_file.rename(columns={0: "County Code", 1: "State FIPS", 2: "County FIPS", 
                                  3: "County_State", 4: "Month", 5: "Labor Force", 6: "Employed", 
                                  7: "Unemployed", 8: "Unemployment Rate (%)"})

unemployment_df.head(10)
# Out:
#                                          County Code State FIPS County FIPS  \
# 0  Labor force data by county, not seasonally adj...        NaN         NaN
# 1                                                NaN        NaN         NaN
# 2                                                NaN      State      County
# 3                                                NaN       FIPS        FIPS
# 4                                          LAUS Code       Code        Code
# 5                                                NaN        NaN         NaN
# 6                                    CN0100100000000         01         001
# 7                                    CN0100300000000         01         003
# 8                                    CN0100500000000         01         005
# 9                                    CN0100700000000         01         007
#
#                      County_State   Month  Labor Force     Employed  \
# 0                             NaN     NaN          NaN          NaN
# 1                             NaN     NaN          NaN          NaN
# 2                             NaN     NaN          NaN          NaN
# 3                             NaN     NaN        Labor          NaN
# 4  County Name/State Abbreviation  Period        Force     Employed
# 5                             NaN     NaN          NaN          NaN
# 6              Autauga County, AL  Nov-17  25,871       25,085
# 7              Baldwin County, AL  Nov-17  90,382       87,439
# 8              Barbour County, AL  Nov-17   8,148        7,766
# 9                 Bibb County, AL  Nov-17   8,455        8,177
#
#    Unemployed Unemployment Rate (%)
# 0         NaN                   NaN
# 1         NaN                   NaN
# 2         NaN             Unemploy-
# 3         NaN             ment Rate
# 4  Unemployed                   (%)
# 5         NaN                   NaN
# 6    786                   3.0
# 7  2,943                   3.3
# 8    382                   4.7
# 9    278                   3.3

# %%
# Remove extra rows that were included from csv formatting
unemployment_df=unemployment_df.drop(unemployment_df.index[:6])
unemployment_df.head(10)
# Out:
#         County Code State FIPS County FIPS         County_State   Month  \
# 6   CN0100100000000         01         001   Autauga County, AL  Nov-17
# 7   CN0100300000000         01         003   Baldwin County, AL  Nov-17
# 8   CN0100500000000         01         005   Barbour County, AL  Nov-17
# 9   CN0100700000000         01         007      Bibb County, AL  Nov-17
# 10  CN0100900000000         01         009    Blount County, AL  Nov-17
# 11  CN0101100000000         01         011   Bullock County, AL  Nov-17
# 12  CN0101300000000         01         013    Butler County, AL  Nov-17
# 13  CN0101500000000         01         015   Calhoun County, AL  Nov-17
# 14  CN0101700000000         01         017  Chambers County, AL  Nov-17
# 15  CN0101900000000         01         019  Cherokee County, AL  Nov-17
#
#     Labor Force     Employed  Unemployed Unemployment Rate (%)
# 6   25,871       25,085         786                   3.0
# 7   90,382       87,439       2,943                   3.3
# 8    8,148        7,766         382                   4.7
# 9    8,455        8,177         278                   3.3
# 10  24,396       23,641         755                   3.1
# 11   4,832        4,636         196                   4.1
# 12   8,842        8,462         380                   4.3
# 13  45,351       43,587       1,764                   3.9
# 14  15,210       14,701         509                   3.3
# 15  11,027       10,671         356                   3.2

# %%
# Use .loc to find unemployment rate at the end of the year
unemployment_df = unemployment_df.loc[unemployment_df["Month"] == "Dec-17"]

# Reset index values
unemployment_df = unemployment_df.reset_index(drop=True)

unemployment_df.head(10)
# Out:
#        County Code State FIPS County FIPS         County_State   Month  \
# 0  CN0100100000000         01         001   Autauga County, AL  Dec-17
# 1  CN0100300000000         01         003   Baldwin County, AL  Dec-17
# 2  CN0100500000000         01         005   Barbour County, AL  Dec-17
# 3  CN0100700000000         01         007      Bibb County, AL  Dec-17
# 4  CN0100900000000         01         009    Blount County, AL  Dec-17
# 5  CN0101100000000         01         011   Bullock County, AL  Dec-17
# 6  CN0101300000000         01         013    Butler County, AL  Dec-17
# 7  CN0101500000000         01         015   Calhoun County, AL  Dec-17
# 8  CN0101700000000         01         017  Chambers County, AL  Dec-17
# 9  CN0101900000000         01         019  Cherokee County, AL  Dec-17
#
#    Labor Force     Employed  Unemployed Unemployment Rate (%)
# 0  25,733       24,952         781                   3.0
# 1  90,001       87,006       2,995                   3.3
# 2   8,074        7,704         370                   4.6
# 3   8,412        8,143         269                   3.2
# 4  24,164       23,434         730                   3.0
# 5   4,689        4,480         209                   4.5
# 6   8,753        8,374         379                   4.3
# 7  45,160       43,425       1,735                   3.8
# 8  15,187       14,693         494                   3.3
# 9  10,922       10,579         343                   3.1

# %%
# All columns are strings with hidden white space.
#Loop through rows of numerical columns to strip white space and remove commas

for row in range(0, len(unemployment_df)):
    string = unemployment_df["Labor Force"][row]
    unemployment_df["Labor Force"][row] = string.strip()
    unemployment_df["Labor Force"][row] = string.replace(",","")
    
    string = unemployment_df["Employed"][row]
    unemployment_df["Employed"][row] = string.strip()
    unemployment_df["Employed"][row] = string.replace(",","")
    
    string = unemployment_df["Unemployed"][row]
    unemployment_df["Unemployed"][row] = string.strip()
    unemployment_df["Unemployed"][row] = string.replace(",","")
    
    string = unemployment_df["Unemployment Rate (%)"][row]
    unemployment_df["Unemployment Rate (%)"][row] = string.strip()
    
# Convert numerical string values to integers
unemployment_df["Labor Force"] = unemployment_df["Labor Force"].astype(int)
unemployment_df["Employed"] = unemployment_df["Employed"].astype(int)
unemployment_df["Unemployed"] = unemployment_df["Unemployed"].astype(int)
unemployment_df["Unemployment Rate (%)"] = unemployment_df["Unemployment Rate (%)"].astype(float)

    
unemployment_df.dtypes
# Out:
# County Code               object
# State FIPS                object
# County FIPS               object
# County_State              object
# Month                     object
# Labor Force                int32
# Employed                   int32
# Unemployed                 int32
# Unemployment Rate (%)    float64
# dtype: object

# %%
# Create empty list variables to store split values
unemployment_counties = []
unemployment_states = []

# Loop through df to split County_State column into County and State
for row in range(0, len(unemployment_df)):
    county_split = unemployment_df["County_State"][row].split(",")
    county_split[0].strip()
    county_split[-1].strip()
    unemployment_counties.append(county_split[0])
    unemployment_states.append(county_split[-1])
    
# Add columns to df
unemployment_df["County"] = unemployment_counties
unemployment_df["State"] = unemployment_states

# Rearrange columns and remove unnecessary columns
unemployment_df = unemployment_df[["County Code", "State FIPS", "County FIPS", "County", "State", "Labor Force", 
                                   "Employed", "Unemployed", "Unemployment Rate (%)"]]

unemployment_df.head(10)
# Out:
#        County Code State FIPS County FIPS           County State  Labor Force  \
# 0  CN0100100000000         01         001   Autauga County    AL        25733
# 1  CN0100300000000         01         003   Baldwin County    AL        90001
# 2  CN0100500000000         01         005   Barbour County    AL         8074
# 3  CN0100700000000         01         007      Bibb County    AL         8412
# 4  CN0100900000000         01         009    Blount County    AL        24164
# 5  CN0101100000000         01         011   Bullock County    AL         4689
# 6  CN0101300000000         01         013    Butler County    AL         8753
# 7  CN0101500000000         01         015   Calhoun County    AL        45160
# 8  CN0101700000000         01         017  Chambers County    AL        15187
# 9  CN0101900000000         01         019  Cherokee County    AL        10922
#
#    Employed  Unemployed  Unemployment Rate (%)
# 0     24952         781                    3.0
# 1     87006        2995                    3.3
# 2      7704         370                    4.6
# 3      8143         269                    3.2
# 4     23434         730                    3.0
# 5      4480         209                    4.5
# 6      8374         379                    4.3
# 7     43425        1735                    3.8
# 8     14693         494                    3.3
# 9     10579         343                    3.1

# %%
# New York City is split into 5 counties for each borough and must be combined into one entry

# Isolate New York Counties from the rest of the df
nyc_df = unemployment_df.loc[unemployment_df["State"] == " NY"]

# Rename each county to New York City
nyc_df.loc[nyc_df["County"] == "New York County", "County"] = "New York City"
nyc_df.loc[nyc_df["County"] == "Kings County", "County"] = "New York City"
nyc_df.loc[nyc_df["County"] == "Bronx County", "County"] = "New York City"
nyc_df.loc[nyc_df["County"] == "Richmond County", "County"] = "New York City"
nyc_df.loc[nyc_df["County"] == "Queens County", "County"] = "New York City"

# Combine all New York City data into one dataframe
nyc_df = nyc_df.loc[nyc_df["County"] == "New York City"]

# Find totals of statistics and find unemployment rate for all 5 boroughs
nyc_labor_force = nyc_df["Labor Force"].sum()
nyc_employed = nyc_df["Employed"].sum()
nyc_unemployed = nyc_df["Unemployed"].sum()
nyc_unemployment_rate = round(nyc_unemployed / nyc_labor_force * 100, 1)

# Make a dataframe using NYC totals
nyc_totals = pd.DataFrame({"County Code": None, "State FIPS": None, "County FIPS": None, "County": "New York City", 
                           "State": "NY", "Labor Force": nyc_labor_force, "Employed": nyc_employed, 
                           "Unemployed": nyc_unemployed, "Unemployment Rate (%)": nyc_unemployment_rate}, index=[0])

# Drop NYC rows from unemployment dataframe
unemployment_df[unemployment_df.County != "New York City"]

# Merge NYC totals into main dataframe to replace dropped rows
unemployment_df = unemployment_df.merge(nyc_totals, how="outer")
unemployment_df.head()
# Out:
#        County Code State FIPS County FIPS           County State  Labor Force  \
# 0  CN0100100000000         01         001   Autauga County    AL        25733
# 1  CN0100300000000         01         003   Baldwin County    AL        90001
# 2  CN0100500000000         01         005   Barbour County    AL         8074
# 3  CN0100700000000         01         007      Bibb County    AL         8412
# 4  CN0100900000000         01         009    Blount County    AL        24164
# 5  CN0101100000000         01         011   Bullock County    AL         4689
# 6  CN0101300000000         01         013    Butler County    AL         8753
# 7  CN0101500000000         01         015   Calhoun County    AL        45160
# 8  CN0101700000000         01         017  Chambers County    AL        15187
# 9  CN0101900000000         01         019  Cherokee County    AL        10922
#
#    Employed  Unemployed  Unemployment Rate (%)
# 0     24952         781                    3.0
# 1     87006        2995                    3.3
# 2      7704         370                    4.6
# 3      8143         269                    3.2
# 4     23434         730                    3.0
# 5      4480         209                    4.5
# 6      8374         379                    4.3
# 7     43425        1735                    3.8
# 8     14693         494                    3.3
# 9     10579         343                    3.1

# %%
unemployment_df.loc[unemployment_df["County"] == "New York City"]
# Out:
#      County Code State FIPS County FIPS         County State  Labor Force  \
# 3219        None       None        None  New York City    NY      4189864
#
#       Employed  Unemployed  Unemployment Rate (%)
# 3219   4023962      165902                    4.0

# %%
# Use geocoder to find county

results = geocoder.google("63121", key=g_key)
print(results.county)
# Out:
# St Louis County

# %%
# Testing api calls from Bureau of Labor Statistics
# Later: add bls_key to config and import
base_url = "https://api.bls.gov/publicAPI/v2/timeseries/data/"
prefix = "LAUCN"


response = requests.get(f"{base_url}/LAUST110000000000003?registrationkey={bls_key}")

# %% [markdown]
# # Carlos

# %% [markdown]
# # Yissel

# %% [markdown]
# # Rodrigo
